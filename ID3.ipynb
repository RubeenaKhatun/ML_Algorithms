# %% [markdown]
# <a href="https://colab.research.google.com/github/RubeenaKhatun/ML_Algorithms/blob/main/ID3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn import preprocessing
from sklearn import tree
data = pd.read_csv("/content/drive/MyDrive/Data.csv")
X = data.iloc[:,:-1]
Y = data.iloc[:,-1]
attributes = X.columns
target_classes = Y.unique()
le = preprocessing.LabelEncoder()
X = X.apply(le.fit_transform)
clt = tree.DecisionTreeClassifier(criterion="entropy")
clt.fit(X,Y)
tree.plot_tree(clt,feature_names=attributes,class_names=target_classes,filled=True)
clt.predict([[0,1,0,1]])
clt.predict([[2,1,0,1]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['No'], dtype=object)
